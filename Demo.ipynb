# %%
import ast

# %%
ast.literal_eval()

# %%
import sys
sys.version
# Out:
# '3.6.6 | packaged by conda-forge | (default, Jul 26 2018, 11:48:23) [MSC v.1900 64 bit (AMD64)]'

# %% [markdown]
# c:/Users/mille/Miniconda3/envs/datascience/Library/bin/

# %%
sys.path.append('C:\\Users\\Miniconda3\\envs\\datascience\\Library\\bin\\')

# %%
sys.path
# Out:
# ['',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\python36.zip',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\DLLs',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib\\site-packages',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib\\site-packages\\win32',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\mille\\Miniconda3\\envs\\datascience\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\mille\\.ipython']

# %%
a = np.zeros((10,10))

# %%
%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
def plotnormal():
    return plt.plot(np.random.randn(1000), np.random.randn(1000), 'o', alpha=0.3)
plotnormal()

# %%
np.zeros_like()

# %% [markdown]
# Errors are shown in informative ways:

# %%
%run non_existent_file
# Out:
# ERROR: File `'non_existent_file.py'` not found.

# %%
x = 1
y = 4
z = y/(1-x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-dc39888fd1d2> in <module>()
#       1 x = 1
#       2 y = 4
# ----> 3 z = y/(1-x)
#
# ZeroDivisionError: division by zero

# %%
ip = get_ipython()

# %%
%install_ext https://raw.github.com/anaderi/ipython-hierarchymagic/master/hierarchymagic.py
# Out:
# Installed hierarchymagic.py. To use it, type:
#   %load_ext hierarchymagic

# %%
%load_ext hierarchymagic

# %% [markdown]
# You need graphviz installed and on your PATH for the following to work.

# %%
%hierarchy get_ipython()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9d6fb4693659> in <module>()
# ----> 1 get_ipython().magic('hierarchy get_ipython()')
#
# C:\Users\millejoh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# C:\Users\millejoh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-126> in hierarchy(self, parameter_s)
#
# C:\Users\millejoh\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# C:\Users\millejoh\.ipython\extensions\hierarchymagic.py in hierarchy(self, parameter_s)
#     245                                graph_attrs={'rankdir': args.rankdir,
#     246                                             'size': '"{0}"'.format(args.size)})
# --> 247         stdout = run_dot(code, format='png')
#     248         display_png(stdout, raw=True)
#     249
#
# C:\Users\millejoh\.ipython\extensions\hierarchymagic.py in run_dot(code, options, format)
#     111         # * http://stackoverflow.com/a/2935727/727827
#     112         p = Popen(dot_args, stdout=PIPE, stdin=PIPE, stderr=PIPE,
# --> 113                   creationflags=0x08000000)
#     114     else:
#     115         p = Popen(dot_args, stdout=PIPE, stdin=PIPE, stderr=PIPE)
#
# C:\Users\millejoh\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     948                                 c2pread, c2pwrite,
#     949                                 errread, errwrite,
# --> 950                                 restore_signals, start_new_session)
#     951         except:
#     952             # Cleanup if the child failed starting.
#
# C:\Users\millejoh\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1218                                          env,
#    1219                                          cwd,
# -> 1220                                          startupinfo)
#    1221             finally:
#    1222                 # Child is launched. Close the parent's copy of those pipe
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# EIN also supports pretty printing from SymPy.

# %%
from sympy.interactive import printing
printing.init_printing()

import sympy as sym
from sympy import *
x, y, z = symbols("x y z")

Rational(3,2)*pi + exp(I*x) / (x**2 + y)

# %% [markdown]
# If you install px can you get the below to work?
#
# $a^2=b$
